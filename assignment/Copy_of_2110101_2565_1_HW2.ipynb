# %% [markdown]
# # 2110101: การบ้านครั้งที่ 2: List, If, Loop
#
#
# **30 คะแนน**
#
# **จุดมุ่งหมายของการบ้าน**
# - เข้าใจคำสั่งและการใช้งาน list, if และ loop
#
# **การส่งงาน**
# - ส่งไฟล์ในรูปแบบ .ipynb ใน MyCourseVille (เลือก File->Download->Download .ipynb)
# - ตั้งชื่อไฟล์เป็น HW2_XXXXXXXXX.ipynb เมื่อ XXXXXXXXXX คือ รหัสนิสิต
# - กำหนดส่ง คือ ก่อน 23:59 น. ของวันอังคารที่ 13 กันยายน 2565
#
# **โจทย์**
#
# กำหนดให้
# - `data` เป็นลิสต์เก็บคะแนนการสอบย่อยของนิสิต โดยเก็บข้อมูลจากซ้ายไปขวาในลิสต์ เป็นเลขประจำตัวตามด้วยคะแนน เลขประจำตัวตามด้วยคะแนน ไปเรื่อย ๆ (<font color=red>เลขประจำตัวที่เหมือนกัน (จะกี่ครั้งก็ตาม) จะอยู่เรียงกันไป</font> และ<font color=blue>คะแนนเป็นจำนวนเต็ม</font>) เช่น
# <pre>
# [
#     <font color=red>6610013121,4</font>,
#     <font color=blue>6610021021,5, 6610021021,5</font>,
#     <font color=green>6610061121,5, 6610061121,5, 6610061121,1</font>,
#     <font color=violet>6610000121,3, 6610000121,2, 6610000121,2, 6610000121,3</font>
# ]
# </pre>
#
# - จงเขียนฟังก์ชัน `get_sum(data)` ซึ่งรับลิสต์ `data` ในรูปแบบข้างต้น (`data` มีขนาดอย่างน้อย 2 ช่องแน่ ๆ) เพื่อสร้างและคืนลิสต์ ที่มีลักษณะดังนี้
#   - เก็บเลขประจำตัวตามด้วย<b><font color=red>คะแนนรวม</font></b> (ที่เป็นจำนวนเต็ม) ของนิสิตที่มีเลขประจำตัวเดียวกัน (เก็บเป็นลำดับในทำนองเดียวกับ `data`) โดยแต่ละเลขประจำตัวมีเก็บเพียงครั้งเดียว
#   - ถ้านิสิตคนนี้มีคะแนนใน `data` เกิน 3 ครั้ง คะแนนรวมของนิสิต จะหักคะแนนที่นิสิตคนนี้ได้<font color=red>น้อยสุด</font>ออก 1 ครั้ง
#   - ลำดับของเลขประจำตัวในลิสต์ (ใครมาก่อนมาหลัง) ต้องเหมือนกับใน `data`
#   - จากตัวอย่างของลิสต์ `data` ข้างต้น ฟังก์ชัน `get_sum(data)` จะ<font color=red>คืนลิสต์</font>ที่มีค่าดังนี้
# <pre>
# [<font color=red>6610013121,4</font>, <font color=blue>6610021021,10</font>, <font color=green>6610061121,11</font>, <font color=violet>6610000121,8</font>]
# </pre>
#
# - ข้อแนะนำ
#   - หาก `x` เป็นลิสต์ และเราอยากจะนำค่าในตัวแปร `e` ไปเก็บต่อท้ายลิสต์ `x` ก็ใช้คำสั่ง `x = x + [e]` หรือเขียนสั้น ๆ `x += [e]`
#
# - ข้อห้าม
#  - ห้ามใช้ dict กับ set
#  - ห้าม import ใด ๆ
#  - ในฟังก์ชันต้องไม่ใช้ตัวแปรนอกฟังก์ชัน
#  - ห้ามเปลี่ยนบรรทัด def ของฟังก์ชันที่ให้เขียน
#  - ฟังก์ชันต้องคืนข้อมูลและประเภทข้อมูลตามที่กำหนดเท่านั้น
#  - ฟังก์ชันต้องไม่ print อะไรใด ๆ ทั้งสิ้น
#
# **อ่านตรงนี้ด้วย**
# - ให้แน่ใจว่า ไม่ดูโปรแกรมของคนอื่น
# - ให้แน่ใจว่า ไม่ได้ให้คนอื่นดูโปรแกรมของตัวเอง
# - ถ้าโปรแกรมการบ้านที่ส่งคล้ายของคนอื่น จนระบบดักได้ว่าส่อทุจริต ไม่ว่าจะเป็นต้นฉบับก็ตาม นิสิตจะได้คะแนน<font color=red>ติดลบเท่ากับผลรวมของทุกการบ้านก่อนนี้</font>
#
# - ไม่รับพิจารณาแฟ้มใด ๆ ที่ส่งเกินเวลา (ต้องส่งในระบบ MyCourseVille เท่านั้น)
# - จะพิจารณาเฉพาะแฟ้มที่ส่งครั้งหลังสุดในระบบ
# - จะตรวจให้คะแนน เมื่อ
#  - แฟ้มที่ส่งครั้งหลังสุดใน MyCourseVille เป็นแฟ้มที่ตั้งชื่อตามที่กำหนด และเป็นแฟ้มที่ได้จากการ File->Download->Download .ipynb เท่านั้น (ไม่ใช่แฟ้ม .py แล้วมา rename เป็น .ipynb)
#  - ฟังก์ชันที่เขียนส่งต้องอยู่ใน code cell สุดท้ายข้างล่างนี้
#  - บรรทัดแรกของ code cell สุดท้ายต้องขึ้นต้นด้วย `# HW02` ตามที่ให้ไป
#  - ไม่ทำในสิ่งที่ห้ามทำในข้อห้าม
#  - code cell สุดท้ายสามารถทำงานได้ (ไม่มี error)
#  - การทำงานในฟังก์ชัน `get_sum` ต้องใช้เวลาไม่นาน (เช่น `data` มีข้อมูลสักหนึ่งแสนช่อง ก็ไม่น่าใช้เวลาเกิน 1 นาที)

# %%
# HW02 (ไม่ลบหรือแก้ไขบรรทัดนี้ หรือเพิ่มอะไรก่อนบรรทัดนี้ โดยเด็ดขาด)
def get_sum(data):
    id = []
    score = []
    for i in range(len(data)):
        if i % 2 == 0:
            id.append(data[i])
        else:
            score.append(data[i])
    count = 1
    sum = 0
    id_output = []
    score_output = []
    for i in range(len(id)):
        if i == 0:
            min_score = score[i]
            sum = sum + score[i]
            count += 1
        else:
            if id[i] == id[i - 1]:
                count += 1
                if score[i] < min_score:
                    min_score = score[i]
                sum = sum + score[i]
                if i == len(id) - 1:
                    id_output.append(id[i])
                    if count > 3:
                        sum = sum - min_score
                    score_output.append(sum)

            else:
                id_output.append(id[i - 1])
                if count > 3:
                    sum = sum - min_score
                score_output.append(sum)
                count = 1
                sum = 0
                sum = sum + score[i]
                min_score = score[i]
    output = []
    for i in range(len(score_output)):
        output.append(id_output[i])
        output.append(score_output[i])
    return output
# -----------------------------
d = [
  6610013121,4,
  6610021021,5, 6610021021,5,
  6610061121,5, 6610061121,5, 6610061121,1,
  6610000121,3, 6610000121,2, 6610000121,2, 6610000121,3
]
out = get_sum(d)
print(out) # ต้องแสดง [6610013121, 4, 6610021021, 10, 6610061121, 11, 6610000121, 8]
# ข้อแนะนำ: ควรทดสอบ get_sum ด้วยข้อมูลชุดอื่นด้วย (ลิสต์ d ข้างบนอาจมีไม่ครอบคลุมทุกกรณี)
# Out:
# [6610013121, 4, 6610021021, 10, 6610061121, 11, 6610000121, 8]
